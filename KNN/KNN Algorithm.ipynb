# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')

# %%
dfx = pd.read_csv('C:\shiu ml\coding-blocks-machine-learning-master\Datasets/xdata.csv')
dfy = pd.read_csv('C:\shiu ml\coding-blocks-machine-learning-master\Datasets/ydata.csv')

# %%
X = dfx.values
Y = dfy.values

X = X[:,1:] #for all rows let us drop the all elements of first column 
Y = Y[:,1:].reshape((-1,))

#print(X)

print(X.shape)
print(Y.shape)

#print(Y)
# Out:
# (399, 2)
# (399,)

# %%
plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %%
query_x = np.array([2,3])
plt.scatter(X[:,0],X[:,1],c=Y)
plt.scatter(query_x[0],query_x[1],color='red')
plt.show()

# %%
def dist(x1,x2):#euclidean dist
    return np.sqrt(sum((x1-x2)**2))

# Test Time 
def knn(X,Y,queryPoint,k=5):
    
    vals = []
    m = X.shape[0]
    
    for i in range(m):
        d = dist(queryPoint,X[i])
        vals.append((d,Y[i]))
        
    
    vals = sorted(vals)
    # Nearest/First K points
    vals = vals[:k]
    
    vals = np.array(vals)
    
    #print(vals)
    
    new_vals = np.unique(vals[:,1],return_counts=True)
    print(new_vals)
    #return vals
    
    index = new_vals[1].argmax()
    pred = new_vals[0][index]
    
    return pred

# %%
x = knn(X,Y,query_x)
print(x)

#this query point belong to class label 0
# Out:
# (array([0., 1.]), array([3, 2], dtype=int64))
# 0.0

# %%
knn(X,Y,query_x)#run this after hashing all lines after  new_vals line
# or after hashing all lines after index line and unhashing the hashed lines
#and the second point will give u result like (array[0,1],array(3,2))where array(3,2) give freuency of label 0 and label 1 present in array(0,1)
# Out:
# 0.0

# %%
x = knn(X,Y,[0,0])
print(x)
x = knn(X,Y,[4,5])
print(x)
# Out:
# (array([1.]), array([5], dtype=int64))
# 1.0
# (array([0.]), array([5], dtype=int64))
# 0.0
