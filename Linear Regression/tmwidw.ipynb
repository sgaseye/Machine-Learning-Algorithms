# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn import preprocessing

# %%
data_train = pd.read_csv("Train/Train_Data.csv")

# %%
empty = np.where(pd.isnull(data_train))
print(empty[0].shape)
coloumns_name = data_train.columns
print(coloumns_name[0])
# Out:
# (5265,)
# Id

# %%
for i in range(empty[0].shape[0]):
    for j in range(empty[1].shape[0]):
        row_no = empty[0][i]
        col_no = empty[1][j]
        col = coloumns_name[col_no]
        data_train.at[row_no,col] = -1

# %%
empty2 = np.where(pd.isnull(data_train))
print(empty2)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
for col_name in data_train.columns:
    le= preprocessing.LabelEncoder()
    print(col_name)
    data_train[col_name] = le.fit_transform(data_train[col_name])
    print(1)
# Out:
# Id
# 1
# MSSubClass
# 1
# MSZoning
# 1
# LotFrontage
# 1
# LotArea
# 1
# Street
# 1
# Alley
# 1
# LotShape
# 1
# LandContour
# 1
# Utilities
# 1
# LotConfig
# 1
# LandSlope
# 1
# Neighborhood
# 1
# Condition1
# 1
# Condition2
# 1
# BldgType
# 1
# HouseStyle
# 1
# OverallQual
# 1
# OverallCond
# 1
# YearBuilt
# 1
# YearRemodAdd
# 1
# RoofStyle
# 1
# RoofMatl
# 1
# Exterior1st
# 1
# Exterior2nd
# 1
# MasVnrType
# 1
# MasVnrArea
# 1
# ExterQual
# 1
# ExterCond
# 1
# Foundation
# 1
# BsmtQual
# 1
# BsmtCond
# 1
# BsmtExposure
# 1
# BsmtFinType1
# 1
# BsmtFinSF1
# 1
# BsmtFinType2
# 1
# BsmtFinSF2
# 1
# BsmtUnfSF
# 1
# TotalBsmtSF
# 1
# Heating
# 1
# HeatingQC
# 1
# CentralAir
# 1
# Electrical
# 1
# 1stFlrSF
# 1
# 2ndFlrSF
# 1
# LowQualFinSF
# 1
# GrLivArea
# 1
# BsmtFullBath
# 1
# BsmtHalfBath
# 1
# FullBath
# 1
# HalfBath
# 1
# BedroomAbvGr
# 1
# KitchenAbvGr
# 1
# KitchenQual
# 1
# TotRmsAbvGrd
# 1
# Functional
# 1
# Fireplaces
# 1
# FireplaceQu
# 1
# GarageType
# 1
# GarageYrBlt
# 1
# GarageFinish
# 1
# GarageCars
# 1
# GarageArea
# 1
# GarageQual
# 1
# GarageCond
# 1
# PavedDrive
# 1
# WoodDeckSF
# 1
# OpenPorchSF
# 1
# EnclosedPorch
# 1
# 3SsnPorch
# 1
# ScreenPorch
# 1
# PoolArea
# 1
# PoolQC
# 1
# Fence
# 1
# MiscFeature
# 1
# MiscVal
# 1
# MoSold
# 1
# YrSold
# 1
# SaleType
# 1
# SaleCondition
# 1
# SalePrice
# 1

# %%
data_train
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        0           5         3            0      269       1      0
# 1        1           0         3            0      403       1      0
# 2        2           5         3            0      556       1      0
# 3        3           6         3            0      397       1      0
# 4        4           5         3            0      738       1      0
# ...    ...         ...       ...          ...      ...     ...    ...
# 1095  1095           0         3            0      372       1      0
# 1096  1096           6         4            0      139       1      0
# 1097  1097          11         3            0       45       1      0
# 1098  1098           4         4            0      109       1      0
# 1099  1099           0         3            0      606       1      0
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# 0            3            3          0  ...         0       0      0
# 1            3            3          0  ...         0       0      0
# 2            0            3          0  ...         0       0      0
# 3            0            3          0  ...         0       0      0
# 4            0            3          0  ...         0       0      0
# ...        ...          ...        ...  ...       ...     ...    ...
# 1095         0            3          0  ...         0       0      0
# 1096         3            3          0  ...         0       0      0
# 1097         3            3          0  ...         0       0      0
# 1098         3            3          0  ...         0       0      0
# 1099         0            3          0  ...         0       0      0
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0               0        0       1       2         8              4        360
# 1               0        0       4       1         8              4        297
# 2               0        0       8       2         8              4        385
# 3               0        0       1       0         8              0        170
# 4               0        0      11       2         8              4        429
# ...           ...      ...     ...     ...       ...            ...        ...
# 1095            0        0       2       1         8              4        277
# 1096            0        0       2       1         8              4        124
# 1097            0        0       9       1         8              4        260
# 1098            0        0       6       3         8              4        126
# 1099            0        0       3       3         0              0        219
#
# [1100 rows x 81 columns]

# %%
data_train.shape
data_train = data_train.values

# %%
Xt = data_train[:,1:-1]
Yt = data_train[:,-1]

# %%
print(Xt.shape)
print(Yt.shape)
# Out:
# (1100, 79)
# (1100,)

# %%
x_train = Xt[:700]
x_val = Xt[700:]
y_train = Yt[:700]
y_val = Yt[700:]

# %%
print(x_train.shape,y_train.shape)
print(x_val.shape,y_val.shape)
# Out:
# (700, 79) (700,)
# (400, 79) (400,)

# %%
Dense?

# %%
from keras import models
from keras.layers import Dense

# %%
model = models.Sequential()
model.add(Dense(20,activation='relu'))
model.add(Dense(20,activation = 'relu'))
model.add(Dense(1))

# %%
model.compile(optimizer='Adam',loss = 'binary_crossentropy',metrics=['accuracy'])

# %%
hist = model.fit(x_train,y_train,epochs = 100,batch_size=50,validation_data=(x_val,y_val))
# Out:
# Train on 700 samples, validate on 400 samples
# Epoch 1/100
# 700/700 [==============================] - 0s 497us/step - loss: -2067.1422 - accuracy: 0.0029 - val_loss: -3151.4706 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 700/700 [==============================] - 0s 31us/step - loss: -3683.6818 - accuracy: 0.0014 - val_loss: -3632.1312 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 700/700 [==============================] - 0s 44us/step - loss: -3813.5257 - accuracy: 0.0029 - val_loss: -3666.9780 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 700/700 [==============================] - 0s 48us/step - loss: -3869.2700 - accuracy: 0.0014 - val_loss: -3685.7352 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 700/700 [==============================] - 0s 41us/step - loss: -3869.6138 - accuracy: 0.0014 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 6/100
# 700/700 [==============================] - 0s 48us/step - loss: -3872.3430 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 7/100
# 700/700 [==============================] - 0s 38us/step - loss: -3872.7254 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 8/100
# 700/700 [==============================] - 0s 50us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 9/100
# 700/700 [==============================] - 0s 41us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 10/100
# 700/700 [==============================] - 0s 37us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 11/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 12/100
# 700/700 [==============================] - 0s 61us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 13/100
# 700/700 [==============================] - 0s 44us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 14/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 15/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 16/100
# 700/700 [==============================] - 0s 40us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 17/100
# 700/700 [==============================] - 0s 51us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 18/100
# 700/700 [==============================] - 0s 53us/step - loss: -3874.9592 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 19/100
# 700/700 [==============================] - 0s 61us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 20/100
# 700/700 [==============================] - 0s 44us/step - loss: -3874.9592 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 21/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 22/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 23/100
# 700/700 [==============================] - 0s 44us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 24/100
# 700/700 [==============================] - 0s 40us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 25/100
# 700/700 [==============================] - 0s 40us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 26/100
# 700/700 [==============================] - 0s 40us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 27/100
# 700/700 [==============================] - 0s 44us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 28/100
# 700/700 [==============================] - 0s 51us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 29/100
# 700/700 [==============================] - 0s 38us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 30/100
# 700/700 [==============================] - 0s 40us/step - loss: -3874.9592 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 31/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9595 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 32/100
# 700/700 [==============================] - 0s 58us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 33/100
# 700/700 [==============================] - 0s 44us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 34/100
# 700/700 [==============================] - 0s 44us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 35/100
# 700/700 [==============================] - 0s 41us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 36/100
# 700/700 [==============================] - 0s 37us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 37/100
# 700/700 [==============================] - 0s 46us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 38/100
# 700/700 [==============================] - 0s 41us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 39/100
# 700/700 [==============================] - 0s 44us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 40/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 41/100
# 700/700 [==============================] - 0s 41us/step - loss: -3874.9592 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 42/100
# 700/700 [==============================] - 0s 36us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 43/100
# 700/700 [==============================] - 0s 34us/step - loss: -3874.9592 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 44/100
# 700/700 [==============================] - 0s 40us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 45/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 46/100
# 700/700 [==============================] - 0s 34us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 47/100
# 700/700 [==============================] - 0s 36us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 48/100
# 700/700 [==============================] - 0s 40us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 49/100
# 700/700 [==============================] - 0s 34us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 50/100
# 700/700 [==============================] - 0s 46us/step - loss: -3874.9592 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 51/100
# 700/700 [==============================] - 0s 64us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 52/100
# 700/700 [==============================] - 0s 47us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 53/100
# 700/700 [==============================] - 0s 48us/step - loss: -3874.9592 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 54/100
# 700/700 [==============================] - 0s 37us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 55/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 56/100
# 700/700 [==============================] - 0s 41us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 57/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 58/100
# 700/700 [==============================] - 0s 38us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 59/100
# 700/700 [==============================] - 0s 36us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 60/100
# 700/700 [==============================] - 0s 41us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 61/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 62/100
# 700/700 [==============================] - ETA: 0s - loss: -3989.0952 - accuracy: 0.0000e+ - 0s 40us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 63/100
# 700/700 [==============================] - 0s 36us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 64/100
# 700/700 [==============================] - 0s 33us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 65/100
# 700/700 [==============================] - 0s 34us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 66/100
# 700/700 [==============================] - 0s 33us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 67/100
# 700/700 [==============================] - 0s 34us/step - loss: -3874.9592 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 68/100
# 700/700 [==============================] - 0s 33us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 69/100
# 700/700 [==============================] - 0s 34us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 70/100
# 700/700 [==============================] - 0s 33us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 71/100
# 700/700 [==============================] - 0s 36us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 72/100
# 700/700 [==============================] - 0s 33us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 73/100
# 700/700 [==============================] - 0s 36us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 74/100
# 700/700 [==============================] - 0s 34us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 75/100
# 700/700 [==============================] - 0s 48us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 76/100
# 700/700 [==============================] - 0s 46us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 77/100
# 700/700 [==============================] - 0s 44us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 78/100
# 700/700 [==============================] - 0s 48us/step - loss: -3874.9595 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 79/100
# 700/700 [==============================] - 0s 40us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 80/100
# 700/700 [==============================] - 0s 46us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 81/100
# 700/700 [==============================] - 0s 46us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 82/100
# 700/700 [==============================] - 0s 44us/step - loss: -3874.9592 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 83/100
# 700/700 [==============================] - 0s 50us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 84/100
# 700/700 [==============================] - 0s 48us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 85/100
# 700/700 [==============================] - 0s 50us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 86/100
# 700/700 [==============================] - 0s 60us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 87/100
# 700/700 [==============================] - 0s 50us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 88/100
# 700/700 [==============================] - 0s 41us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 89/100
# 700/700 [==============================] - 0s 38us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 90/100
# 700/700 [==============================] - 0s 33us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 91/100
# 700/700 [==============================] - 0s 38us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 92/100
# 700/700 [==============================] - 0s 37us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 93/100
# 700/700 [==============================] - 0s 31us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 94/100
# 700/700 [==============================] - 0s 33us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 95/100
# 700/700 [==============================] - 0s 34us/step - loss: -3874.9594 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 96/100
# 700/700 [==============================] - 0s 36us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 97/100
# 700/700 [==============================] - 0s 33us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 98/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 99/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025
# Epoch 100/100
# 700/700 [==============================] - 0s 43us/step - loss: -3874.9593 - accuracy: 0.0029 - val_loss: -3685.7352 - val_accuracy: 0.0025

# %%
model.evaluate(x_train,y_train)
# Out:
# 700/700 [==============================] - 0s 14us/step
# [-3853.5576785714284, 0.0028571428265422583]
